# %%
from datasets import load_dataset
# Out:
# /Users/haozhang/opt/anaconda3/lib/python3.8/site-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.12) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
wiki = load_dataset("wikicorpus", "raw_en")
# Out:
# ...
# Reusing dataset wikicorpus (/Users/haozhang/.cache/huggingface/datasets/wikicorpus/raw_en/0.0.0/6dff92752a49f4e34e7562070fd35f469a684a915648fabfc18c7bdd25fde3bd)
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
wiki
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'title', 'text'],
#         num_rows: 1359146
#     })
# })

# %%
wiki["train"][:2]
# Out:
# {'id': ['214730', '7986334'],
#  'title': ['Henry Hallam', 'Sungai Besi LRT station'],
# ...

# %%
wiki_shuffle = wiki.shuffle()

# %%
wiki_shuffle["train"][:2]
# Out:
# {'id': ['6990238', '2202177'],
#  'title': ['ChampionChip', 'Faisal Ahmad Shinwari'],
# ...
